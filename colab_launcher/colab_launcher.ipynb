# %% [markdown]
# ### Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Clone codebase into current colab workspace

# %%
# !rm -rf gdn-ad-sh
# !git clone https://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@github.com/houcine1amraoui/gdn-ad-sh.git
# %cd gdn-ad-sh
# Out:
# Cloning into 'gdn-ad-sh'...
# remote: Enumerating objects: 2117, done.
# remote: Counting objects: 100% (250/250), done.
# remote: Compressing objects: 100% (180/180), done.
# remote: Total 2117 (delta 166), reused 139 (delta 69), pack-reused 1867 (from 1)
# Receiving objects: 100% (2117/2117), 859.38 KiB | 9.66 MiB/s, done.
# Resolving deltas: 100% (1467/1467), done.
# /content/gdn-ad-sh

# %% [markdown]
# ### Overide configs

# %%
import yaml
from pathlib import Path
PROJECT_ROOT_DIR = "/content/drive/MyDrive/02_research/td_gdn/implementation" # change this to the actual directory in your Google Drive
config_override = {
    "project_root_dir": PROJECT_ROOT_DIR,

    "seed": 42,

    "preprocessing": {
        "dataset_folder": "data",
        "merge_bre_cu": False,
        "dataset_name": "CU",
        "apply_filtering": True,
        "apply_cleaning": True,
        "downsample_freq": "1s",
        "val_ratio": 0.1,
        "actors_timelines": {
            "actor1_t1_start": "2022-10-18 00:00:00",
            "actor1_t1_end": "2022-11-07 23:59:59",
            "actor2_start": "2022-11-08 00:00:00",
            "actor2_end": "2022-11-10 23:59:59",
            "actor1_t2_start": "2022-11-11 00:00:00",
            "actor1_t2_end": "2022-11-17 23:59:59",
        }
    },

    "models": [
        {
            "name": "gdn",
            "enabled": True,
            "params": {
                "hidden_dim": 64,
                "topk": 15,
                "heads": 1
            }
        },
        {
            "name": "mtad_gat",
            "enabled": True,
            "params": {
                "kernel_size": 5,
                "gru_hidden_dim": 100,
                "gat_heads": 2
            }
        }
    ],

    "training": {
        "model": "mtad_gat",
        "window_size": 30,
        "batch_size": 32,
        "epochs": 50,
        "lr": 0.0001,
        "patience": 10
    },

    "evaluation": {
        "model": "mtad_gat",
        "batch_size": 32,
        "combine_errors": True,
        "score_aggregation": "max", # mean or max
        "score_smoothing_enabled": True,
        "score_smoothing_window": 5,
        "threshold_percentile": 99
    }
}
repo_path = "/content/gdn-ad-sh"
config_path = Path(repo_path) / "configs/config.yaml"

with open(config_path, "w") as f:
    yaml.dump(config_override, f, sort_keys=False)

print("config.yaml overridden successfully")
# Out:
# config.yaml overridden successfully

# %% [markdown]
# ### Install additional dependencies (do not come with Colab by default)

# %%
from IPython.display import clear_output
import torch

# !pip install torch-geometric

if torch.cuda.is_available():
  # !pip install torch-cluster -f https://data.pyg.org/whl/torch-2.10.0+cu128.html
else:
  # !pip install torch-cluster -f https://data.pyg.org/whl/torch-2.10.0+cpu.html

clear_output()

# %% [markdown]
# ### Run data preprocessing

# %%
# !python -m main_preprocess --project_root_dir $PROJECT_ROOT_DIR

# %% [markdown]
# ### Run model training

# %%
# !python -m main_train --project_root_dir $PROJECT_ROOT_DIR

# %% [markdown]
# ### Run model evaluation

# %%
# !python -m main_evaluation --project_root_dir $PROJECT_ROOT_DIR
# Out:
# Computing scores...
# Smoothing scores...
# Computing point-wise metrics...
# {'threshold': np.float64(0.01947527259588242), 'threshold_percentile': 90, 'score_type': 'combined', 'detection_rate': np.float64(0.7482579002199329), 'false_positive_rate': np.float64(0.1)}

# %% [markdown]
# ### Run results visualization

# %%
# !python -m main_visualization --project_root_dir $PROJECT_ROOT_DIR
